# %%
import pandas as pd

# Load data (adjust path)
df = pd.read_csv ("/Users/firdaus/Desktop/Firdaus/sample data/SAML-D.csv")

# Check basic info
print (df.head())
print (df.info())
print (df.describe())
# Out:
#        Time        Date  Sender_account  Receiver_account    Amount  \
# 0  10:35:19  2022-10-07      8724731955        2769355426   1459.15
# 1  10:35:20  2022-10-07      1491989064        8401255335   6019.64
# 2  10:35:20  2022-10-07       287305149        4404767002  14328.44
# 3  10:35:21  2022-10-07      5376652437        9600420220  11895.00
# 4  10:35:21  2022-10-07      9614186178        3803336972    115.25
#
#   Payment_currency Received_currency Sender_bank_location  \
# 0        UK pounds         UK pounds                   UK
# 1        UK pounds            Dirham                   UK
# 2        UK pounds         UK pounds                   UK
# 3        UK pounds         UK pounds                   UK
# 4        UK pounds         UK pounds                   UK
#
#   Receiver_bank_location  Payment_type  Is_laundering       Laundering_type
# 0                     UK  Cash Deposit              0  Normal_Cash_Deposits
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Date', 'Sender_account', 'Receiver_account', 'Amount',
#        'Payment_currency', 'Received_currency', 'Sender_bank_location',
#        'Receiver_bank_location', 'Payment_type', 'Is_laundering',
#        'Laundering_type'],
#       dtype='object')

# %%
percentiles = df['Amount'].quantile([0.80, 0.90, 0.95, 0.99])
print = percentiles

# %%
pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 7.3 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 7.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 7.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]m6/8 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matpolib
# Out:
# ERROR: Could not find a version that satisfies the requirement matpolib (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# ERROR: No matching distribution found for matpolib
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Amount'], bins=100, log_scale=(True, False))
plt.title("Transaction Amount Distribution")
plt.show()

# %%
thresholds = df['Amount'].quantile([0.90, 0.95, 0.99])

# %%
import pandas as pd

df = pd.read_csv("/Users/firdaus/Desktop/Firdaus/sample data/SAML-D.csv")

thresholds = df['Amount'].quantile([0.90, 0.95, 0.99])

for t in thresholds:
    flagged = df[df['Amount'] > t]
    flagged_count = flagged.shape[0]
    __builtins__.print(f"Threshold: {t:.2f}, Alerts: {flagged_count}")
# Out:
# Threshold: 16560.85, Alerts: 950485
# Threshold: 22039.51, Alerts: 475243
# Threshold: 45021.55, Alerts: 95049

# %%
for t in thresholds:
    flagged = df[df['Amount'] > t]
    laundering_hits = flagged['Is_laundering'].sum()
    total_alerts = flagged.shape[0]

    __builtins__.print(
        f"Threshold {t:.2f} | Alerts: {total_alerts} | Laundering caught: {laundering_hits}"
    )
# Out:
# Threshold 16560.85 | Alerts: 950485 | Laundering caught: 1300
# Threshold 22039.51 | Alerts: 475243 | Laundering caught: 939
# Threshold 45021.55 | Alerts: 95049 | Laundering caught: 437
